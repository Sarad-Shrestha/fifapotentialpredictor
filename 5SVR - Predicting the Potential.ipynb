# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.offline as pyo
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('players_20.csv')

# %% [markdown]
# ###### Showing all columns

# %%
pd.options.display.max_columns = None
display(df.head())
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 3        188         87    Slovenia      Atlético Madrid       91         93
# 4        175         74     Belgium          Real Madrid       91         91
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 3   77500000    125000               GK          Right
# 4   90000000    470000           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# 1                         5          4            5       High/Low
# 2                         5          5            5    High/Medium
# 3                         3          3            1  Medium/Medium
# 4                         4          4            4    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  40                  30                     43
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
# 4                         27                        22                  11
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
# 4                    12                    6                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                    89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                     8  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
# 4  61+3  49+3  49+3  49+3  61+3

# %% [markdown]
# ###### Seperating out the X and Y - Goalkeeper Skill Prediction

# %%
goalkeeper = df[df['team_position'] == 'GK']
goalkeeper.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
#
#       short_name              long_name  age         dob  height_cm  \
# 3       J. Oblak              Jan Oblak   26  1993-01-07        188
# 6  M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
#
#    weight_kg nationality             club  overall  potential  value_eur  \
# 3         87    Slovenia  Atlético Madrid       91         93   77500000
# 6         85     Germany     FC Barcelona       90         93   67500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 3    125000               GK          Right                         3
# 6    250000               GK          Right                         3
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 3          3            1  Medium/Medium    Normal       Yes
# 6          4            1  Medium/Medium    Normal       Yes
#
#    release_clause_eur player_tags team_position  team_jersey_number  \
# 3         164700000.0         NaN            GK                13.0
# 6         143400000.0         NaN            GK                 1.0
#
#   loaned_from      joined  contract_valid_until nation_position  \
# 3         NaN  2014-07-16                2023.0              GK
# 6         NaN  2014-07-01                2022.0             SUB
#
#    nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 3                   1.0   NaN       NaN      NaN        NaN        NaN
# 6                  22.0   NaN       NaN      NaN        NaN        NaN
#
#    physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 3     NaN       87.0         92.0        78.0         89.0      52.0
# 6     NaN       88.0         85.0        88.0         90.0      45.0
#
#    gk_positioning                                   player_traits  \
# 3            90.0                      Flair, Acrobatic Clearance
# 6            88.0  Swerve Pass, Acrobatic Clearance, Flair Passes
#
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 3                  13                   11                          15
# 6                  18                   14                          11
#
#    attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 3                       43                 13               12           13
# 6                       61                 14               21           18
#
#    skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 3                 14                  40                  30
# 6                 12                  63                  30
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 3                     43                     60                67
# 6                     38                     50                37
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 3                  88                49                59             78
# 6                  86                43                66             79
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 3             41              78                12                    34
# 6             35              78                10                    43
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 3                       19                     11                65
# 6                       22                     11                70
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 3                   11                   68                 27
# 6                   25                   70                 25
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 3                         12                        18                  87
# 6                         13                        10                  88
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 3                    92                   78                       90
# 6                    85                   88                       88
#
#    goalkeeping_reflexes   ls   st   rs   lw   lf   cf   rf   rw  lam  cam  \
# 3                    89  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6                    90  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    ram   lm  lcm   cm  rcm   rm  lwb  ldm  cdm  rdm  rwb   lb  lcb   cb  rcb  \
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     rb
# 3  NaN
# 6  NaN

# %%
X = goalkeeper[['age', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_strength', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_composure']]
y = goalkeeper['potential']

# %% [markdown]
# ###### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(X)
scaled_features
# Out:
# array([[-0.54,  2.5 ,  3.78, ..., -0.34,  1.68,  1.5 ],
#        [-0.32,  2.65,  2.7 , ..., -0.34,  2.05,  1.66],
#        [-0.54,  2.2 ,  2.54, ...,  0.19,  1.75,  1.26],
#        ...,
#        [ 0.11, -2.16, -0.57, ..., -1.14, -1.4 , -1.44],
#        [-2.48, -2.46, -2.12, ..., -1.68, -0.59, -0.88],
#        [-1.4 , -2.92, -2.59, ..., -0.08, -0.74, -1.04]])

# %%
# Convert the Scaled Features into a Dataframe
X = pd.DataFrame(scaled_features, columns = X.columns[:])
X.head()
# Out:
#         age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 0 -0.540724   2.502270     3.784263    1.733179     2.453364  1.053455
# 1 -0.324956   2.652765     2.696810    3.179498     2.594543  0.326252
# 2 -0.540724   2.201279     2.541459    2.745602     2.453364  0.949569
# 3 -0.109188   2.953756     2.541459    2.167075     2.876902  1.676771
# 4 -0.756492   2.351775     2.230758    3.902657     2.312185  2.196202
#
#    gk_positioning  movement_acceleration  movement_sprint_speed  \
# 0        3.113224               0.134033               1.792949
# 1        2.818360              -0.357274               0.794772
# 2        3.113224               1.411432               0.495319
# 3        2.376063               1.509694               1.593313
# 4        2.523495               2.197524               2.092402
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0          1.977822            2.693575          0.433760          1.798413
# 1         -0.567179            2.457397         -0.119514          3.146060
# 2         -0.312679            2.693575         -0.672787          2.761018
# 3          1.638488            2.575486         -0.119514          2.183455
# 4          1.383988            2.575486          0.341547          3.916144
#
#    power_jumping  power_strength  mentality_aggression  \
# 0       1.543688        1.388857              0.848870
# 1       1.633433        1.388857              2.018791
# 2      -0.789671        1.388857             -0.061068
# 3       0.556498       -0.282315              1.368835
# 4       0.466753        0.460428              1.368835
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                 0.109448              -0.343274          1.680149
# 1                 0.656965              -0.343274          2.046481
# 2                -1.350597               0.190171          1.753415
# 3                 2.117010              -0.076552          1.680149
# 4                 1.569493               2.057229          2.046481
#
#    mentality_composure
# 0             1.499864
# 1             1.658806
# 2             1.261451
# 3             1.499864
# 4             1.658806

# %% [markdown]
# ###### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state = 1)

# %%
X_train.head(2)
# Out:
#           age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 593  1.832725  -1.260115    -1.342303   -1.014826    -1.358478  0.637911
# 458 -1.188028  -0.056152    -0.410200   -0.870194    -0.229043  0.430139
#
#      gk_positioning  movement_acceleration  movement_sprint_speed  \
# 593       -0.720012               0.625341               0.595137
# 458       -1.162309               0.232295               0.595137
#
#      movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 593          0.111488           -0.258655          0.249335         -1.089401
# 458         -0.397512           -0.967190          1.355882         -0.896880
#
#      power_jumping  power_strength  mentality_aggression  \
# 593      -1.417883        0.553271              2.148782
# 458      -0.879415       -0.839373             -0.971007
#
#      mentality_interceptions  mentality_positioning  mentality_vision  \
# 593                -0.073057              -1.143442         -0.517846
# 458                 1.386988               0.723616         -1.763376
#
#      mentality_composure
# 593             1.023038
# 458             0.069387

# %%
X_test.head(2)
# Out:
#           age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 306  0.538116  -0.056152     0.055851   -0.002403    -0.511402  0.741797
# 658  0.106580  -2.313582    -1.963705   -2.027249    -2.064374 -0.089292
#
#      gk_positioning  movement_acceleration  movement_sprint_speed  \
# 306        0.312013               0.330556               1.094225
# 658       -2.046902              -0.160751              -0.003770
#
#      movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 306         -0.397512            0.095613          0.618184          0.065725
# 658          0.874988           -2.148082          0.433760         -2.052006
#
#      power_jumping  power_strength  mentality_aggression  \
# 306        0.01803        1.110328              0.198914
# 658       -0.96916       -0.189472              0.848870
#
#      mentality_interceptions  mentality_positioning  mentality_vision  \
# 306                 1.751999               1.523784         -0.224780
# 658                -1.350597               0.190171         -2.349508
#
#      mentality_composure
# 306            -0.089555
# 658            -0.169026

# %%
y_test.head(2)
# Out:
# 5290     70
# 17341    57
# Name: potential, dtype: int64

# %%
y_train.head(2)
# Out:
# 12925    63
# 8985     74
# Name: potential, dtype: int64

# %% [markdown]
# ## Regression Models

# %% [markdown]
# ###### Fitting the Model

# %%
from sklearn.svm import SVR

# %%
regressor = SVR(kernel = 'rbf')

# %%
regressor.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning:
#
# The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ###### Prediction from the Model

# %%
#Passing in a dataset the model has never seen before = X_Test
predictions = regressor.predict(X_test)

# %% [markdown]
# ###### Comparing with y_test and predictions

# %%
#Converting y_test into an Array since predictions is an array as well
y_test1 = np.array(y_test)

np.set_printoptions(precision=2) #Limiting to 2 decimal places

print(np.concatenate((predictions.reshape(len(predictions),1), y_test1.reshape(len(y_test1),1)),1))
# Out:
# [[70.45 70.  ]
#  [67.14 57.  ]
#  [82.52 86.  ]
#  [75.04 76.  ]
#  [73.1  75.  ]
#  [72.95 75.  ]
#  [66.77 61.  ]
#  [84.31 84.  ]
#  [65.09 65.  ]
#  [70.23 74.  ]
#  [70.35 66.  ]
#  [69.51 69.  ]
#  [69.34 65.  ]
#  [77.08 77.  ]
#  [67.05 66.  ]
#  [81.44 80.  ]
#  [78.05 79.  ]
#  [70.7  71.  ]
#  [69.28 68.  ]
#  [68.55 68.  ]
#  [74.03 74.  ]
#  [74.38 73.  ]
#  [74.66 76.  ]
#  [69.66 72.  ]
#  [77.13 74.  ]
#  [74.23 78.  ]
#  [76.11 77.  ]
#  [66.79 66.  ]
#  [71.99 72.  ]
#  [70.3  69.  ]
#  [69.17 69.  ]
#  [69.38 55.  ]
#  [72.53 73.  ]
#  [68.01 68.  ]
#  [71.   72.  ]
#  [67.57 69.  ]
#  [71.35 70.  ]
#  [65.75 64.  ]
#  [72.72 74.  ]
#  [67.45 65.  ]
#  [73.42 76.  ]
#  [84.43 86.  ]
#  [71.86 71.  ]
#  [75.86 79.  ]
#  [80.03 83.  ]
#  [66.5  65.  ]
#  [71.84 69.  ]
#  [79.22 80.  ]
#  [72.55 75.  ]
#  [72.17 75.  ]
#  [70.71 71.  ]
#  [69.8  73.  ]
#  [74.19 74.  ]
#  [63.7  63.  ]
#  [67.44 65.  ]
#  [76.38 75.  ]
#  [65.86 62.  ]
#  [68.21 67.  ]
#  [71.46 77.  ]
#  [74.43 75.  ]
#  [70.25 70.  ]
#  [75.01 82.  ]
#  [68.64 64.  ]
#  [77.63 79.  ]
#  [69.52 65.  ]
#  [71.86 71.  ]
#  [68.64 69.  ]
#  [67.   65.  ]
#  [71.33 72.  ]
#  [70.15 69.  ]
#  [78.67 80.  ]
#  [70.04 70.  ]
#  [71.85 71.  ]
#  [67.74 67.  ]
#  [67.78 69.  ]
#  [72.73 78.  ]
#  [70.35 64.  ]
#  [84.03 84.  ]
#  [71.06 78.  ]
#  [67.32 67.  ]
#  [70.61 72.  ]
#  [68.15 67.  ]
#  [63.73 62.  ]
#  [73.04 76.  ]
#  [67.71 68.  ]
#  [72.57 73.  ]
#  [77.03 77.  ]
#  [80.18 93.  ]
#  [83.25 84.  ]
#  [70.33 70.  ]
#  [66.51 67.  ]
#  [78.44 79.  ]
#  [80.04 78.  ]
#  [69.18 68.  ]
#  [68.05 69.  ]
#  [71.7  71.  ]
#  [78.27 85.  ]
#  [78.17 79.  ]
#  [73.56 77.  ]
#  [67.06 64.  ]
#  [79.78 85.  ]
#  [82.56 82.  ]
#  [76.82 79.  ]
#  [79.   87.  ]
#  [74.41 75.  ]
#  [79.71 79.  ]
#  [71.38 71.  ]
#  [65.35 65.  ]
#  [73.73 72.  ]
#  [69.31 70.  ]
#  [78.5  83.  ]
#  [69.15 68.  ]
#  [70.35 67.  ]
#  [74.47 75.  ]
#  [71.92 81.  ]
#  [71.27 75.  ]
#  [73.12 74.  ]
#  [72.27 72.  ]
#  [78.36 77.  ]
#  [78.67 81.  ]
#  [71.58 72.  ]
#  [71.52 74.  ]
#  [69.96 72.  ]
#  [67.   67.  ]
#  [80.56 83.  ]
#  [72.01 72.  ]
#  [73.33 76.  ]
#  [72.64 74.  ]
#  [70.58 70.  ]
#  [70.58 69.  ]
#  [67.48 68.  ]
#  [69.03 72.  ]
#  [76.35 76.  ]
#  [68.82 67.  ]
#  [69.07 68.  ]
#  [71.31 70.  ]
#  [68.14 67.  ]
#  [73.45 73.  ]
#  [74.08 73.  ]
#  [80.08 80.  ]
#  [68.17 68.  ]
#  [70.19 71.  ]
#  [73.84 75.  ]
#  [72.47 74.  ]
#  [67.78 68.  ]
#  [69.87 69.  ]
#  [72.88 73.  ]
#  [70.36 69.  ]
#  [77.51 78.  ]
#  [72.84 74.  ]
#  [83.58 87.  ]
#  [73.89 76.  ]
#  [70.14 69.  ]
#  [66.33 66.  ]
#  [71.14 73.  ]
#  [69.35 68.  ]
#  [67.2  67.  ]
#  [69.49 70.  ]
#  [69.38 69.  ]
#  [65.51 65.  ]
#  [79.48 79.  ]
#  [69.7  68.  ]
#  [68.62 65.  ]
#  [72.85 72.  ]
#  [77.54 78.  ]
#  [73.65 82.  ]
#  [66.67 62.  ]
#  [80.22 90.  ]
#  [69.13 58.  ]
#  [83.53 88.  ]
#  [69.88 68.  ]
#  [66.83 63.  ]
#  [70.6  69.  ]
#  [72.36 73.  ]
#  [67.47 67.  ]
#  [67.25 67.  ]
#  [71.74 79.  ]
#  [73.34 73.  ]
#  [76.77 78.  ]
#  [83.83 85.  ]
#  [66.97 67.  ]
#  [83.05 89.  ]
#  [74.67 79.  ]
#  [72.03 73.  ]
#  [71.06 74.  ]
#  [77.27 82.  ]
#  [68.42 66.  ]
#  [70.58 69.  ]
#  [73.69 74.  ]
#  [70.84 69.  ]
#  [74.02 74.  ]
#  [80.69 79.  ]
#  [78.87 79.  ]
#  [82.65 87.  ]
#  [70.89 71.  ]
#  [65.34 66.  ]
#  [70.38 69.  ]
#  [78.67 82.  ]
#  [70.76 74.  ]
#  [66.92 67.  ]
#  [65.92 63.  ]
#  [70.81 69.  ]
#  [70.07 69.  ]
#  [68.7  67.  ]
#  [82.56 86.  ]
#  [73.85 78.  ]
#  [69.65 69.  ]
#  [70.14 69.  ]
#  [79.12 77.  ]
#  [74.26 79.  ]
#  [69.39 71.  ]
#  [74.78 76.  ]
#  [67.88 70.  ]
#  [73.66 75.  ]
#  [71.25 75.  ]
#  [80.39 81.  ]
#  [70.21 70.  ]
#  [69.29 69.  ]
#  [81.19 80.  ]
#  [72.28 71.  ]
#  [74.04 75.  ]
#  [79.84 79.  ]
#  [69.96 69.  ]
#  [71.43 72.  ]
#  [74.89 76.  ]
#  [71.18 70.  ]
#  [79.37 79.  ]
#  [71.66 74.  ]
#  [69.03 72.  ]
#  [80.85 87.  ]
#  [69.96 68.  ]
#  [76.93 91.  ]
#  [78.14 86.  ]
#  [69.29 69.  ]
#  [71.32 71.  ]
#  [71.12 71.  ]
#  [82.56 84.  ]
#  [72.16 73.  ]
#  [72.56 73.  ]
#  [63.86 62.  ]
#  [66.29 65.  ]
#  [75.94 76.  ]
#  [70.46 66.  ]
#  [79.41 78.  ]
#  [78.78 80.  ]
#  [79.99 80.  ]
#  [75.59 78.  ]
#  [68.02 68.  ]
#  [77.4  82.  ]
#  [81.75 84.  ]
#  [65.43 59.  ]
#  [78.9  78.  ]
#  [75.5  75.  ]
#  [72.91 73.  ]
#  [71.89 72.  ]
#  [67.94 66.  ]
#  [65.83 65.  ]
#  [74.15 74.  ]
#  [64.05 62.  ]
#  [65.79 67.  ]
#  [69.6  71.  ]
#  [72.6  73.  ]
#  [71.82 77.  ]
#  [71.17 75.  ]
#  [70.59 70.  ]
#  [65.17 65.  ]
#  [67.72 69.  ]
#  [76.25 75.  ]
#  [67.72 67.  ]
#  [64.69 61.  ]
#  [68.41 66.  ]
#  [79.26 79.  ]
#  [81.51 82.  ]
#  [70.81 70.  ]
#  [70.   70.  ]
#  [80.47 84.  ]
#  [67.23 69.  ]
#  [75.07 77.  ]
#  [75.6  80.  ]
#  [75.17 76.  ]
#  [68.97 67.  ]
#  [67.88 68.  ]
#  [73.45 71.  ]
#  [69.22 67.  ]
#  [76.5  75.  ]
#  [66.55 65.  ]
#  [80.86 88.  ]
#  [71.77 71.  ]
#  [66.48 63.  ]
#  [72.19 72.  ]
#  [67.69 69.  ]
#  [80.75 80.  ]
#  [71.42 72.  ]
#  [70.74 68.  ]
#  [71.92 81.  ]
#  [72.88 73.  ]
#  [70.13 69.  ]
#  [71.84 75.  ]
#  [63.97 63.  ]
#  [79.33 91.  ]
#  [68.38 68.  ]
#  [76.5  79.  ]
#  [82.82 87.  ]
#  [75.06 73.  ]
#  [83.63 84.  ]
#  [73.76 74.  ]
#  [72.19 73.  ]
#  [72.49 74.  ]
#  [73.46 74.  ]
#  [67.04 66.  ]
#  [65.73 66.  ]
#  [74.3  76.  ]
#  [66.89 64.  ]
#  [68.37 67.  ]
#  [66.34 62.  ]
#  [77.47 77.  ]
#  [72.01 73.  ]
#  [70.71 71.  ]
#  [73.14 74.  ]
#  [68.   70.  ]
#  [77.08 78.  ]
#  [75.14 76.  ]
#  [69.59 68.  ]
#  [66.65 56.  ]
#  [67.13 68.  ]
#  [83.93 83.  ]
#  [72.04 76.  ]
#  [73.13 73.  ]
#  [75.23 76.  ]
#  [73.99 76.  ]
#  [73.77 75.  ]]

# %% [markdown]
# ##### Putting the Predictions into the Dataset

# %%
X_test.head(2)
# Out:
#           age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 306  0.538116  -0.056152     0.055851   -0.002403    -0.511402  0.741797
# 658  0.106580  -2.313582    -1.963705   -2.027249    -2.064374 -0.089292
#
#      gk_positioning  movement_acceleration  movement_sprint_speed  \
# 306        0.312013               0.330556               1.094225
# 658       -2.046902              -0.160751              -0.003770
#
#      movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 306         -0.397512            0.095613          0.618184          0.065725
# 658          0.874988           -2.148082          0.433760         -2.052006
#
#      power_jumping  power_strength  mentality_aggression  \
# 306        0.01803        1.110328              0.198914
# 658       -0.96916       -0.189472              0.848870
#
#      mentality_interceptions  mentality_positioning  mentality_vision  \
# 306                 1.751999               1.523784         -0.224780
# 658                -1.350597               0.190171         -2.349508
#
#      mentality_composure
# 306            -0.089555
# 658            -0.169026

# %%
y_test.head(2)
# Out:
# 5290     70
# 17341    57
# Name: potential, dtype: int64

# %%
y_test1
# Out:
# array([70, 57, 86, 76, 75, 75, 61, 84, 65, 74, 66, 69, 65, 77, 66, 80, 79,
#        71, 68, 68, 74, 73, 76, 72, 74, 78, 77, 66, 72, 69, 69, 55, 73, 68,
#        72, 69, 70, 64, 74, 65, 76, 86, 71, 79, 83, 65, 69, 80, 75, 75, 71,
#        73, 74, 63, 65, 75, 62, 67, 77, 75, 70, 82, 64, 79, 65, 71, 69, 65,
#        72, 69, 80, 70, 71, 67, 69, 78, 64, 84, 78, 67, 72, 67, 62, 76, 68,
#        73, 77, 93, 84, 70, 67, 79, 78, 68, 69, 71, 85, 79, 77, 64, 85, 82,
#        79, 87, 75, 79, 71, 65, 72, 70, 83, 68, 67, 75, 81, 75, 74, 72, 77,
#        81, 72, 74, 72, 67, 83, 72, 76, 74, 70, 69, 68, 72, 76, 67, 68, 70,
#        67, 73, 73, 80, 68, 71, 75, 74, 68, 69, 73, 69, 78, 74, 87, 76, 69,
#        66, 73, 68, 67, 70, 69, 65, 79, 68, 65, 72, 78, 82, 62, 90, 58, 88,
#        68, 63, 69, 73, 67, 67, 79, 73, 78, 85, 67, 89, 79, 73, 74, 82, 66,
#        69, 74, 69, 74, 79, 79, 87, 71, 66, 69, 82, 74, 67, 63, 69, 69, 67,
#        86, 78, 69, 69, 77, 79, 71, 76, 70, 75, 75, 81, 70, 69, 80, 71, 75,
#        79, 69, 72, 76, 70, 79, 74, 72, 87, 68, 91, 86, 69, 71, 71, 84, 73,
#        73, 62, 65, 76, 66, 78, 80, 80, 78, 68, 82, 84, 59, 78, 75, 73, 72,
#        66, 65, 74, 62, 67, 71, 73, 77, 75, 70, 65, 69, 75, 67, 61, 66, 79,
#        82, 70, 70, 84, 69, 77, 80, 76, 67, 68, 71, 67, 75, 65, 88, 71, 63,
#        72, 69, 80, 72, 68, 81, 73, 69, 75, 63, 91, 68, 79, 87, 73, 84, 74,
#        73, 74, 74, 66, 66, 76, 64, 67, 62, 77, 73, 71, 74, 70, 78, 76, 68,
#        56, 68, 83, 76, 73, 76, 76, 75], dtype=int64)

# %%
predictions
# Out:
# array([70.45, 67.14, 82.52, 75.04, 73.1 , 72.95, 66.77, 84.31, 65.09,
#        70.23, 70.35, 69.51, 69.34, 77.08, 67.05, 81.44, 78.05, 70.7 ,
#        69.28, 68.55, 74.03, 74.38, 74.66, 69.66, 77.13, 74.23, 76.11,
#        66.79, 71.99, 70.3 , 69.17, 69.38, 72.53, 68.01, 71.  , 67.57,
#        71.35, 65.75, 72.72, 67.45, 73.42, 84.43, 71.86, 75.86, 80.03,
#        66.5 , 71.84, 79.22, 72.55, 72.17, 70.71, 69.8 , 74.19, 63.7 ,
#        67.44, 76.38, 65.86, 68.21, 71.46, 74.43, 70.25, 75.01, 68.64,
#        77.63, 69.52, 71.86, 68.64, 67.  , 71.33, 70.15, 78.67, 70.04,
#        71.85, 67.74, 67.78, 72.73, 70.35, 84.03, 71.06, 67.32, 70.61,
#        68.15, 63.73, 73.04, 67.71, 72.57, 77.03, 80.18, 83.25, 70.33,
#        66.51, 78.44, 80.04, 69.18, 68.05, 71.7 , 78.27, 78.17, 73.56,
#        67.06, 79.78, 82.56, 76.82, 79.  , 74.41, 79.71, 71.38, 65.35,
#        73.73, 69.31, 78.5 , 69.15, 70.35, 74.47, 71.92, 71.27, 73.12,
#        72.27, 78.36, 78.67, 71.58, 71.52, 69.96, 67.  , 80.56, 72.01,
#        73.33, 72.64, 70.58, 70.58, 67.48, 69.03, 76.35, 68.82, 69.07,
#        71.31, 68.14, 73.45, 74.08, 80.08, 68.17, 70.19, 73.84, 72.47,
#        67.78, 69.87, 72.88, 70.36, 77.51, 72.84, 83.58, 73.89, 70.14,
#        66.33, 71.14, 69.35, 67.2 , 69.49, 69.38, 65.51, 79.48, 69.7 ,
#        68.62, 72.85, 77.54, 73.65, 66.67, 80.22, 69.13, 83.53, 69.88,
#        66.83, 70.6 , 72.36, 67.47, 67.25, 71.74, 73.34, 76.77, 83.83,
#        66.97, 83.05, 74.67, 72.03, 71.06, 77.27, 68.42, 70.58, 73.69,
#        70.84, 74.02, 80.69, 78.87, 82.65, 70.89, 65.34, 70.38, 78.67,
#        70.76, 66.92, 65.92, 70.81, 70.07, 68.7 , 82.56, 73.85, 69.65,
#        70.14, 79.12, 74.26, 69.39, 74.78, 67.88, 73.66, 71.25, 80.39,
#        70.21, 69.29, 81.19, 72.28, 74.04, 79.84, 69.96, 71.43, 74.89,
#        71.18, 79.37, 71.66, 69.03, 80.85, 69.96, 76.93, 78.14, 69.29,
#        71.32, 71.12, 82.56, 72.16, 72.56, 63.86, 66.29, 75.94, 70.46,
#        79.41, 78.78, 79.99, 75.59, 68.02, 77.4 , 81.75, 65.43, 78.9 ,
#        75.5 , 72.91, 71.89, 67.94, 65.83, 74.15, 64.05, 65.79, 69.6 ,
#        72.6 , 71.82, 71.17, 70.59, 65.17, 67.72, 76.25, 67.72, 64.69,
#        68.41, 79.26, 81.51, 70.81, 70.  , 80.47, 67.23, 75.07, 75.6 ,
#        75.17, 68.97, 67.88, 73.45, 69.22, 76.5 , 66.55, 80.86, 71.77,
#        66.48, 72.19, 67.69, 80.75, 71.42, 70.74, 71.92, 72.88, 70.13,
#        71.84, 63.97, 79.33, 68.38, 76.5 , 82.82, 75.06, 83.63, 73.76,
#        72.19, 72.49, 73.46, 67.04, 65.73, 74.3 , 66.89, 68.37, 66.34,
#        77.47, 72.01, 70.71, 73.14, 68.  , 77.08, 75.14, 69.59, 66.65,
#        67.13, 83.93, 72.04, 73.13, 75.23, 73.99, 73.77])

# %%
#Adding the Actual Potential into the X_test dataset

# %%
X_test['Potential Skill'] = y_test1

# %%
#Adding the Predicted skill into the dataset

# %%
X_test['Predicted Skill'] = predictions

# %%
X_test.head(3)
# Out:
#           age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 306  0.538116  -0.056152     0.055851   -0.002403    -0.511402  0.741797
# 658  0.106580  -2.313582    -1.963705   -2.027249    -2.064374 -0.089292
# 47  -1.188028   1.448802     1.609356    1.154652     1.465109  0.845683
#
#      gk_positioning  movement_acceleration  movement_sprint_speed  \
# 306        0.312013               0.330556               1.094225
# 658       -2.046902              -0.160751              -0.003770
# 47         1.491470               1.116648               0.595137
#
#      movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 306         -0.397512            0.095613          0.618184          0.065725
# 658          0.874988           -2.148082          0.433760         -2.052006
# 47           1.723322            1.748862         -1.318273          1.220850
#
#      power_jumping  power_strength  mentality_aggression  \
# 306        0.01803        1.110328              0.198914
# 658       -0.96916       -0.189472              0.848870
# 47         0.01803        0.646114             -0.191060
#
#      mentality_interceptions  mentality_positioning  mentality_vision  \
# 306                 1.751999               1.523784         -0.224780
# 658                -1.350597               0.190171         -2.349508
# 47                  0.474460              -0.343274          1.313816
#
#      mentality_composure  Potential Skill  Predicted Skill
# 306            -0.089555               70        70.453476
# 658            -0.169026               57        67.137781
# 47              1.181980               86        82.518952

# %% [markdown]
# ###### Mapping the Predicted Skill into the main dataset

# %%
## Merging on Index
#df_merged = df.merge(X_test, how='outer', left_index=True, right_index=True)

# %%
#Dropping values with NAN for Predicted Skill
#df_merged = df_merged.dropna(subset=['Predicted Skill'])

# %%
#Selecting on the basis of row
#df_merged.loc[:, ['short_name', 'potential', 'Potential Skill', 'Predicted Skill']]

# %% [markdown]
# ###### Model Evaluation

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions))) #The Lower the better
# Out:
# MAE: 2.006663467648945
# MSE: 9.481645268243716
# RMSE: 3.0792280312188174

# %% [markdown]
# ###### Calculate the R2

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predictions)
# Out:
# 0.7836831232463508
