# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.offline as pyo
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('players_20.csv')

# %% [markdown]
# ###### Showing all columns

# %%
pd.options.display.max_columns = None
display(df.head())
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 3        188         87    Slovenia      Atlético Madrid       91         93
# 4        175         74     Belgium          Real Madrid       91         91
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 3   77500000    125000               GK          Right
# 4   90000000    470000           LW, CF          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            4     Medium/Low
# 1                         5          4            5       High/Low
# 2                         5          5            5    High/Medium
# 3                         3          3            1  Medium/Medium
# 4                         4          4            4    High/Medium
#
#     body_type real_face  release_clause_eur  \
# 0       Messi       Yes         195800000.0
# 1  C. Ronaldo       Yes          96500000.0
# 2      Neymar       Yes         195200000.0
# 3      Normal       Yes         164700000.0
# 4      Normal       Yes         184500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                NaN            GK
# 4                    #Speedster, #Dribbler, #Acrobat            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
# 2                10.0         NaN  2017-08-03                2022.0
# 3                13.0         NaN  2014-07-16                2023.0
# 4                 7.0         NaN  2019-07-01                2024.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
# 2              LW                  10.0  91.0      85.0     87.0       95.0
# 3              GK                   1.0   NaN       NaN      NaN        NaN
# 4              LF                  10.0  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
# 2       32.0    58.0        NaN          NaN         NaN          NaN
# 3        NaN     NaN       87.0         92.0        78.0         89.0
# 4       35.0    66.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3      52.0            90.0
# 4       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3                         Flair, Acrobatic Clearance                  13
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  40                  30                     43
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     60                67                  88
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                49                59             78             41
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              78                12                    34
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       19                     11                65
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   11                   68                 27
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
# 2                         26                        29                   9
# 3                         12                        18                  87
# 4                         27                        22                  11
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                     9                   15                       15
# 3                    92                   78                       90
# 4                    12                    6                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
# 2                    11  84+3  84+3  84+3  90+3  89+3  89+3  89+3  90+3  90+3
# 3                    89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                     8  83+3  83+3  83+3  89+3  88+3  88+3  88+3  89+3  89+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3  61+3  66+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3  63+3  66+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3
# 2  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN
# 4  61+3  49+3  49+3  49+3  61+3

# %% [markdown]
# ###### Seperating out the X and Y - Goalkeeper Skill Prediction

# %%
goalkeeper = df[df['team_position'] == 'GK']
goalkeeper.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
#
#       short_name              long_name  age         dob  height_cm  \
# 3       J. Oblak              Jan Oblak   26  1993-01-07        188
# 6  M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
#
#    weight_kg nationality             club  overall  potential  value_eur  \
# 3         87    Slovenia  Atlético Madrid       91         93   77500000
# 6         85     Germany     FC Barcelona       90         93   67500000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 3    125000               GK          Right                         3
# 6    250000               GK          Right                         3
#
#    weak_foot  skill_moves      work_rate body_type real_face  \
# 3          3            1  Medium/Medium    Normal       Yes
# 6          4            1  Medium/Medium    Normal       Yes
#
#    release_clause_eur player_tags team_position  team_jersey_number  \
# 3         164700000.0         NaN            GK                13.0
# 6         143400000.0         NaN            GK                 1.0
#
#   loaned_from      joined  contract_valid_until nation_position  \
# 3         NaN  2014-07-16                2023.0              GK
# 6         NaN  2014-07-01                2022.0             SUB
#
#    nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 3                   1.0   NaN       NaN      NaN        NaN        NaN
# 6                  22.0   NaN       NaN      NaN        NaN        NaN
#
#    physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 3     NaN       87.0         92.0        78.0         89.0      52.0
# 6     NaN       88.0         85.0        88.0         90.0      45.0
#
#    gk_positioning                                   player_traits  \
# 3            90.0                      Flair, Acrobatic Clearance
# 6            88.0  Swerve Pass, Acrobatic Clearance, Flair Passes
#
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 3                  13                   11                          15
# 6                  18                   14                          11
#
#    attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 3                       43                 13               12           13
# 6                       61                 14               21           18
#
#    skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 3                 14                  40                  30
# 6                 12                  63                  30
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 3                     43                     60                67
# 6                     38                     50                37
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 3                  88                49                59             78
# 6                  86                43                66             79
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 3             41              78                12                    34
# 6             35              78                10                    43
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 3                       19                     11                65
# 6                       22                     11                70
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 3                   11                   68                 27
# 6                   25                   70                 25
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 3                         12                        18                  87
# 6                         13                        10                  88
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 3                    92                   78                       90
# 6                    85                   88                       88
#
#    goalkeeping_reflexes   ls   st   rs   lw   lf   cf   rf   rw  lam  cam  \
# 3                    89  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6                    90  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#    ram   lm  lcm   cm  rcm   rm  lwb  ldm  cdm  rdm  rwb   lb  lcb   cb  rcb  \
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     rb
# 3  NaN
# 6  NaN

# %%
X = goalkeeper[['age', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_strength', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_composure']]
y = goalkeeper['potential']

# %% [markdown]
# ###### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state = 1)

# %%
X_train.head(2)
# Out:
#        age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 12925   37       62.0         59.0        59.0         62.0      48.0
# 8985    23       70.0         65.0        60.0         70.0      46.0
#
#        gk_positioning  movement_acceleration  movement_sprint_speed  \
# 12925            64.0                     48                     48
# 8985             61.0                     44                     48
#
#        movement_agility  movement_reactions  movement_balance  \
# 12925                45                  63                47
# 8985                 39                  57                59
#
#        power_shot_power  power_jumping  power_strength  mentality_aggression  \
# 12925                44             45              69                    44
# 8985                 45             51              54                    20
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 12925                       18                      8                35
# 8985                        26                     15                18
#
#        mentality_composure
# 12925                   62
# 8985                    50

# %%
X_test.head(2)
# Out:
#        age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 5290    31       70.0         68.0        66.0         68.0      49.0
# 17341   29       55.0         55.0        52.0         57.0      41.0
#
#        gk_positioning  movement_acceleration  movement_sprint_speed  \
# 5290             71.0                     45                     53
# 17341            55.0                     40                     42
#
#        movement_agility  movement_reactions  movement_balance  \
# 5290                 39                  66                51
# 17341                54                  47                49
#
#        power_shot_power  power_jumping  power_strength  mentality_aggression  \
# 5290                 50             61              75                    29
# 17341                39             50              61                    34
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 5290                        28                     18                39
# 17341                       11                     13                10
#
#        mentality_composure
# 5290                    48
# 17341                   47

# %%
y_test.head(2)
# Out:
# 5290     70
# 17341    57
# Name: potential, dtype: int64

# %%
y_train.head(2)
# Out:
# 12925    63
# 8985     74
# Name: potential, dtype: int64

# %% [markdown]
# ## Regression Models

# %% [markdown]
# ###### Fitting the Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators = 15, random_state = 0)

# %%
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=15,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %% [markdown]
# ###### Prediction from the Model

# %%
#Passing in a dataset the model has never seen before = X_Test
predictions = regressor.predict(X_test)

# %% [markdown]
# ###### Comparing with y_test and predictions

# %%
#Converting y_test into an Array since predictions is an array as well
y_test1 = np.array(y_test)

np.set_printoptions(precision=2) #Limiting to 2 decimal places

print(np.concatenate((predictions.reshape(len(predictions),1), y_test1.reshape(len(y_test1),1)),1))
# Out:
# [[71.   70.  ]
#  [62.4  57.  ]
#  [84.53 86.  ]
#  [77.4  76.  ]
#  [73.4  75.  ]
#  [71.53 75.  ]
#  [62.2  61.  ]
#  [84.67 84.  ]
#  [65.87 65.  ]
#  [71.07 74.  ]
#  [68.67 66.  ]
#  [70.73 69.  ]
#  [66.8  65.  ]
#  [77.2  77.  ]
#  [65.67 66.  ]
#  [81.73 80.  ]
#  [81.87 79.  ]
#  [70.2  71.  ]
#  [68.87 68.  ]
#  [67.8  68.  ]
#  [74.13 74.  ]
#  [72.53 73.  ]
#  [76.2  76.  ]
#  [69.8  72.  ]
#  [74.   74.  ]
#  [75.47 78.  ]
#  [78.   77.  ]
#  [64.6  66.  ]
#  [70.6  72.  ]
#  [68.07 69.  ]
#  [70.67 69.  ]
#  [63.07 55.  ]
#  [72.6  73.  ]
#  [67.53 68.  ]
#  [71.07 72.  ]
#  [67.73 69.  ]
#  [74.2  70.  ]
#  [67.73 64.  ]
#  [71.8  74.  ]
#  [66.67 65.  ]
#  [72.27 76.  ]
#  [85.   86.  ]
#  [73.4  71.  ]
#  [77.33 79.  ]
#  [84.07 83.  ]
#  [65.53 65.  ]
#  [69.73 69.  ]
#  [80.4  80.  ]
#  [72.67 75.  ]
#  [73.67 75.  ]
#  [69.73 71.  ]
#  [69.6  73.  ]
#  [72.4  74.  ]
#  [63.53 63.  ]
#  [66.2  65.  ]
#  [75.87 75.  ]
#  [62.6  62.  ]
#  [66.67 67.  ]
#  [71.4  77.  ]
#  [76.53 75.  ]
#  [71.2  70.  ]
#  [78.53 82.  ]
#  [64.67 64.  ]
#  [78.67 79.  ]
#  [66.4  65.  ]
#  [70.87 71.  ]
#  [67.07 69.  ]
#  [64.87 65.  ]
#  [71.27 72.  ]
#  [70.07 69.  ]
#  [78.47 80.  ]
#  [69.4  70.  ]
#  [74.33 71.  ]
#  [67.67 67.  ]
#  [66.93 69.  ]
#  [75.73 78.  ]
#  [63.33 64.  ]
#  [84.47 84.  ]
#  [71.73 78.  ]
#  [68.33 67.  ]
#  [71.4  72.  ]
#  [69.4  67.  ]
#  [62.47 62.  ]
#  [75.53 76.  ]
#  [70.2  68.  ]
#  [73.07 73.  ]
#  [76.2  77.  ]
#  [88.13 93.  ]
#  [84.   84.  ]
#  [72.33 70.  ]
#  [69.4  67.  ]
#  [81.4  79.  ]
#  [78.8  78.  ]
#  [69.53 68.  ]
#  [67.2  69.  ]
#  [71.53 71.  ]
#  [82.   85.  ]
#  [81.07 79.  ]
#  [75.47 77.  ]
#  [66.2  64.  ]
#  [80.6  85.  ]
#  [79.67 82.  ]
#  [77.73 79.  ]
#  [87.27 87.  ]
#  [75.53 75.  ]
#  [76.67 79.  ]
#  [69.67 71.  ]
#  [64.53 65.  ]
#  [72.4  72.  ]
#  [68.33 70.  ]
#  [81.33 83.  ]
#  [68.   68.  ]
#  [71.27 67.  ]
#  [73.13 75.  ]
#  [73.2  81.  ]
#  [70.33 75.  ]
#  [71.8  74.  ]
#  [71.53 72.  ]
#  [77.47 77.  ]
#  [81.67 81.  ]
#  [73.07 72.  ]
#  [72.2  74.  ]
#  [70.2  72.  ]
#  [68.13 67.  ]
#  [81.8  83.  ]
#  [72.   72.  ]
#  [73.07 76.  ]
#  [74.   74.  ]
#  [69.07 70.  ]
#  [71.2  69.  ]
#  [68.73 68.  ]
#  [67.93 72.  ]
#  [73.93 76.  ]
#  [68.87 67.  ]
#  [67.6  68.  ]
#  [69.2  70.  ]
#  [65.4  67.  ]
#  [73.53 73.  ]
#  [72.6  73.  ]
#  [82.13 80.  ]
#  [68.07 68.  ]
#  [72.47 71.  ]
#  [74.   75.  ]
#  [73.93 74.  ]
#  [65.93 68.  ]
#  [70.27 69.  ]
#  [72.   73.  ]
#  [71.73 69.  ]
#  [77.87 78.  ]
#  [75.2  74.  ]
#  [86.8  87.  ]
#  [75.27 76.  ]
#  [68.47 69.  ]
#  [65.93 66.  ]
#  [69.2  73.  ]
#  [68.93 68.  ]
#  [67.87 67.  ]
#  [70.8  70.  ]
#  [69.2  69.  ]
#  [66.   65.  ]
#  [77.47 79.  ]
#  [70.53 68.  ]
#  [65.33 65.  ]
#  [71.33 72.  ]
#  [78.8  78.  ]
#  [74.73 82.  ]
#  [63.4  62.  ]
#  [89.6  90.  ]
#  [62.8  58.  ]
#  [85.33 88.  ]
#  [69.87 68.  ]
#  [64.87 63.  ]
#  [69.47 69.  ]
#  [72.2  73.  ]
#  [66.47 67.  ]
#  [65.93 67.  ]
#  [73.27 79.  ]
#  [72.   73.  ]
#  [76.87 78.  ]
#  [82.47 85.  ]
#  [70.07 67.  ]
#  [86.33 89.  ]
#  [77.67 79.  ]
#  [73.93 73.  ]
#  [71.   74.  ]
#  [79.   82.  ]
#  [66.33 66.  ]
#  [69.4  69.  ]
#  [76.27 74.  ]
#  [69.67 69.  ]
#  [74.93 74.  ]
#  [79.53 79.  ]
#  [78.53 79.  ]
#  [86.2  87.  ]
#  [71.33 71.  ]
#  [66.33 66.  ]
#  [70.33 69.  ]
#  [80.87 82.  ]
#  [70.87 74.  ]
#  [66.4  67.  ]
#  [64.13 63.  ]
#  [66.6  69.  ]
#  [69.6  69.  ]
#  [67.07 67.  ]
#  [84.47 86.  ]
#  [76.07 78.  ]
#  [69.67 69.  ]
#  [67.67 69.  ]
#  [78.27 77.  ]
#  [76.6  79.  ]
#  [71.4  71.  ]
#  [73.53 76.  ]
#  [69.47 70.  ]
#  [74.87 75.  ]
#  [74.27 75.  ]
#  [79.4  81.  ]
#  [69.33 70.  ]
#  [68.2  69.  ]
#  [80.07 80.  ]
#  [71.47 71.  ]
#  [74.13 75.  ]
#  [79.27 79.  ]
#  [65.27 69.  ]
#  [70.07 72.  ]
#  [77.6  76.  ]
#  [68.93 70.  ]
#  [76.2  79.  ]
#  [76.13 74.  ]
#  [67.4  72.  ]
#  [83.87 87.  ]
#  [68.2  68.  ]
#  [88.2  91.  ]
#  [84.73 86.  ]
#  [70.73 69.  ]
#  [72.47 71.  ]
#  [66.13 71.  ]
#  [85.33 84.  ]
#  [73.33 73.  ]
#  [72.   73.  ]
#  [62.6  62.  ]
#  [69.2  65.  ]
#  [77.53 76.  ]
#  [69.13 66.  ]
#  [79.13 78.  ]
#  [76.   80.  ]
#  [83.53 80.  ]
#  [76.6  78.  ]
#  [67.2  68.  ]
#  [82.47 82.  ]
#  [80.87 84.  ]
#  [61.53 59.  ]
#  [79.33 78.  ]
#  [74.67 75.  ]
#  [71.33 73.  ]
#  [71.67 72.  ]
#  [65.47 66.  ]
#  [64.07 65.  ]
#  [73.47 74.  ]
#  [63.13 62.  ]
#  [66.   67.  ]
#  [71.33 71.  ]
#  [73.8  73.  ]
#  [71.6  77.  ]
#  [70.4  75.  ]
#  [69.67 70.  ]
#  [63.2  65.  ]
#  [67.87 69.  ]
#  [74.   75.  ]
#  [69.8  67.  ]
#  [62.73 61.  ]
#  [69.47 66.  ]
#  [77.47 79.  ]
#  [83.73 82.  ]
#  [68.73 70.  ]
#  [72.47 70.  ]
#  [83.67 84.  ]
#  [70.27 69.  ]
#  [75.2  77.  ]
#  [79.67 80.  ]
#  [75.   76.  ]
#  [69.73 67.  ]
#  [66.93 68.  ]
#  [71.87 71.  ]
#  [68.2  67.  ]
#  [76.87 75.  ]
#  [65.8  65.  ]
#  [88.8  88.  ]
#  [72.07 71.  ]
#  [63.67 63.  ]
#  [72.93 72.  ]
#  [69.6  69.  ]
#  [80.27 80.  ]
#  [72.93 72.  ]
#  [69.33 68.  ]
#  [72.4  81.  ]
#  [71.2  73.  ]
#  [68.13 69.  ]
#  [71.6  75.  ]
#  [63.27 63.  ]
#  [87.53 91.  ]
#  [67.67 68.  ]
#  [79.6  79.  ]
#  [85.47 87.  ]
#  [72.73 73.  ]
#  [82.33 84.  ]
#  [73.53 74.  ]
#  [71.73 73.  ]
#  [71.2  74.  ]
#  [77.67 74.  ]
#  [68.6  66.  ]
#  [66.27 66.  ]
#  [76.8  76.  ]
#  [63.87 64.  ]
#  [67.93 67.  ]
#  [63.27 62.  ]
#  [76.07 77.  ]
#  [73.2  73.  ]
#  [72.33 71.  ]
#  [73.93 74.  ]
#  [68.27 70.  ]
#  [77.4  78.  ]
#  [76.67 76.  ]
#  [69.47 68.  ]
#  [62.53 56.  ]
#  [67.73 68.  ]
#  [82.33 83.  ]
#  [73.07 76.  ]
#  [74.67 73.  ]
#  [72.4  76.  ]
#  [75.13 76.  ]
#  [76.4  75.  ]]

# %% [markdown]
# ##### Putting the Predictions into the Dataset

# %%
X_test.head(2)
# Out:
#        age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 5290    31       70.0         68.0        66.0         68.0      49.0
# 17341   29       55.0         55.0        52.0         57.0      41.0
#
#        gk_positioning  movement_acceleration  movement_sprint_speed  \
# 5290             71.0                     45                     53
# 17341            55.0                     40                     42
#
#        movement_agility  movement_reactions  movement_balance  \
# 5290                 39                  66                51
# 17341                54                  47                49
#
#        power_shot_power  power_jumping  power_strength  mentality_aggression  \
# 5290                 50             61              75                    29
# 17341                39             50              61                    34
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 5290                        28                     18                39
# 17341                       11                     13                10
#
#        mentality_composure
# 5290                    48
# 17341                   47

# %%
y_test.head(2)
# Out:
# 5290     70
# 17341    57
# Name: potential, dtype: int64

# %%
y_test1
# Out:
# array([70, 57, 86, 76, 75, 75, 61, 84, 65, 74, 66, 69, 65, 77, 66, 80, 79,
#        71, 68, 68, 74, 73, 76, 72, 74, 78, 77, 66, 72, 69, 69, 55, 73, 68,
#        72, 69, 70, 64, 74, 65, 76, 86, 71, 79, 83, 65, 69, 80, 75, 75, 71,
#        73, 74, 63, 65, 75, 62, 67, 77, 75, 70, 82, 64, 79, 65, 71, 69, 65,
#        72, 69, 80, 70, 71, 67, 69, 78, 64, 84, 78, 67, 72, 67, 62, 76, 68,
#        73, 77, 93, 84, 70, 67, 79, 78, 68, 69, 71, 85, 79, 77, 64, 85, 82,
#        79, 87, 75, 79, 71, 65, 72, 70, 83, 68, 67, 75, 81, 75, 74, 72, 77,
#        81, 72, 74, 72, 67, 83, 72, 76, 74, 70, 69, 68, 72, 76, 67, 68, 70,
#        67, 73, 73, 80, 68, 71, 75, 74, 68, 69, 73, 69, 78, 74, 87, 76, 69,
#        66, 73, 68, 67, 70, 69, 65, 79, 68, 65, 72, 78, 82, 62, 90, 58, 88,
#        68, 63, 69, 73, 67, 67, 79, 73, 78, 85, 67, 89, 79, 73, 74, 82, 66,
#        69, 74, 69, 74, 79, 79, 87, 71, 66, 69, 82, 74, 67, 63, 69, 69, 67,
#        86, 78, 69, 69, 77, 79, 71, 76, 70, 75, 75, 81, 70, 69, 80, 71, 75,
#        79, 69, 72, 76, 70, 79, 74, 72, 87, 68, 91, 86, 69, 71, 71, 84, 73,
#        73, 62, 65, 76, 66, 78, 80, 80, 78, 68, 82, 84, 59, 78, 75, 73, 72,
#        66, 65, 74, 62, 67, 71, 73, 77, 75, 70, 65, 69, 75, 67, 61, 66, 79,
#        82, 70, 70, 84, 69, 77, 80, 76, 67, 68, 71, 67, 75, 65, 88, 71, 63,
#        72, 69, 80, 72, 68, 81, 73, 69, 75, 63, 91, 68, 79, 87, 73, 84, 74,
#        73, 74, 74, 66, 66, 76, 64, 67, 62, 77, 73, 71, 74, 70, 78, 76, 68,
#        56, 68, 83, 76, 73, 76, 76, 75], dtype=int64)

# %%
predictions
# Out:
# array([71.  , 62.4 , 84.53, 77.4 , 73.4 , 71.53, 62.2 , 84.67, 65.87,
#        71.07, 68.67, 70.73, 66.8 , 77.2 , 65.67, 81.73, 81.87, 70.2 ,
#        68.87, 67.8 , 74.13, 72.53, 76.2 , 69.8 , 74.  , 75.47, 78.  ,
#        64.6 , 70.6 , 68.07, 70.67, 63.07, 72.6 , 67.53, 71.07, 67.73,
#        74.2 , 67.73, 71.8 , 66.67, 72.27, 85.  , 73.4 , 77.33, 84.07,
#        65.53, 69.73, 80.4 , 72.67, 73.67, 69.73, 69.6 , 72.4 , 63.53,
#        66.2 , 75.87, 62.6 , 66.67, 71.4 , 76.53, 71.2 , 78.53, 64.67,
#        78.67, 66.4 , 70.87, 67.07, 64.87, 71.27, 70.07, 78.47, 69.4 ,
#        74.33, 67.67, 66.93, 75.73, 63.33, 84.47, 71.73, 68.33, 71.4 ,
#        69.4 , 62.47, 75.53, 70.2 , 73.07, 76.2 , 88.13, 84.  , 72.33,
#        69.4 , 81.4 , 78.8 , 69.53, 67.2 , 71.53, 82.  , 81.07, 75.47,
#        66.2 , 80.6 , 79.67, 77.73, 87.27, 75.53, 76.67, 69.67, 64.53,
#        72.4 , 68.33, 81.33, 68.  , 71.27, 73.13, 73.2 , 70.33, 71.8 ,
#        71.53, 77.47, 81.67, 73.07, 72.2 , 70.2 , 68.13, 81.8 , 72.  ,
#        73.07, 74.  , 69.07, 71.2 , 68.73, 67.93, 73.93, 68.87, 67.6 ,
#        69.2 , 65.4 , 73.53, 72.6 , 82.13, 68.07, 72.47, 74.  , 73.93,
#        65.93, 70.27, 72.  , 71.73, 77.87, 75.2 , 86.8 , 75.27, 68.47,
#        65.93, 69.2 , 68.93, 67.87, 70.8 , 69.2 , 66.  , 77.47, 70.53,
#        65.33, 71.33, 78.8 , 74.73, 63.4 , 89.6 , 62.8 , 85.33, 69.87,
#        64.87, 69.47, 72.2 , 66.47, 65.93, 73.27, 72.  , 76.87, 82.47,
#        70.07, 86.33, 77.67, 73.93, 71.  , 79.  , 66.33, 69.4 , 76.27,
#        69.67, 74.93, 79.53, 78.53, 86.2 , 71.33, 66.33, 70.33, 80.87,
#        70.87, 66.4 , 64.13, 66.6 , 69.6 , 67.07, 84.47, 76.07, 69.67,
#        67.67, 78.27, 76.6 , 71.4 , 73.53, 69.47, 74.87, 74.27, 79.4 ,
#        69.33, 68.2 , 80.07, 71.47, 74.13, 79.27, 65.27, 70.07, 77.6 ,
#        68.93, 76.2 , 76.13, 67.4 , 83.87, 68.2 , 88.2 , 84.73, 70.73,
#        72.47, 66.13, 85.33, 73.33, 72.  , 62.6 , 69.2 , 77.53, 69.13,
#        79.13, 76.  , 83.53, 76.6 , 67.2 , 82.47, 80.87, 61.53, 79.33,
#        74.67, 71.33, 71.67, 65.47, 64.07, 73.47, 63.13, 66.  , 71.33,
#        73.8 , 71.6 , 70.4 , 69.67, 63.2 , 67.87, 74.  , 69.8 , 62.73,
#        69.47, 77.47, 83.73, 68.73, 72.47, 83.67, 70.27, 75.2 , 79.67,
#        75.  , 69.73, 66.93, 71.87, 68.2 , 76.87, 65.8 , 88.8 , 72.07,
#        63.67, 72.93, 69.6 , 80.27, 72.93, 69.33, 72.4 , 71.2 , 68.13,
#        71.6 , 63.27, 87.53, 67.67, 79.6 , 85.47, 72.73, 82.33, 73.53,
#        71.73, 71.2 , 77.67, 68.6 , 66.27, 76.8 , 63.87, 67.93, 63.27,
#        76.07, 73.2 , 72.33, 73.93, 68.27, 77.4 , 76.67, 69.47, 62.53,
#        67.73, 82.33, 73.07, 74.67, 72.4 , 75.13, 76.4 ])

# %%
#Adding the Actual Potential into the X_test dataset

# %%
X_test['Potential Skill'] = y_test1

# %%
#Adding the Predicted skill into the dataset

# %%
X_test['Predicted Skill'] = predictions

# %%
X_test.head(3)
# Out:
#        age  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 5290    31       70.0         68.0        66.0         68.0      49.0
# 17341   29       55.0         55.0        52.0         57.0      41.0
# 427     23       80.0         78.0        74.0         82.0      50.0
#
#        gk_positioning  movement_acceleration  movement_sprint_speed  \
# 5290             71.0                     45                     53
# 17341            55.0                     40                     42
# 427              79.0                     53                     48
#
#        movement_agility  movement_reactions  movement_balance  \
# 5290                 39                  66                51
# 17341                54                  47                49
# 427                  64                  80                30
#
#        power_shot_power  power_jumping  power_strength  mentality_aggression  \
# 5290                 50             61              75                    29
# 17341                39             50              61                    34
# 427                  56             61              70                    26
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 5290                        28                     18                39
# 17341                       11                     13                10
# 427                         21                     11                60
#
#        mentality_composure  Potential Skill  Predicted Skill
# 5290                    48               70        71.000000
# 17341                   47               57        62.400000
# 427                     64               86        84.533333

# %% [markdown]
# ###### Mapping the Predicted Skill into the main dataset

# %%
## Merging on Index
df_merged = df.merge(X_test, how='outer', left_index=True, right_index=True)

# %%
#Dropping values with NAN for Predicted Skill
df_merged = df_merged.dropna(subset=['Predicted Skill'])

# %%
#Selecting on the basis of row
df_merged.loc[:, ['short_name', 'potential', 'Potential Skill', 'Predicted Skill']]
# Out:
#         short_name  potential  Potential Skill  Predicted Skill
# 3         J. Oblak         93             93.0        88.133333
# 13         Alisson         91             91.0        87.533333
# 14          De Gea         90             90.0        89.600000
# 25         Ederson         91             91.0        88.200000
# 28     T. Courtois         89             89.0        86.333333
# ...            ...        ...              ...              ...
# 16335  Dong Chunyu         58             58.0        62.800000
# 16961  Bao Yaxiong         65             65.0        66.800000
# 17072     Shen Jun         56             56.0        62.533333
# 17341  M. McGinley         57             57.0        62.400000
# 17349      Guo Wei         55             55.0        63.066667
#
# [331 rows x 4 columns]

# %% [markdown]
# ###### Model Evaluation

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions))) #The Lower the better
# Out:
# MAE: 1.574823766364552
# MSE: 4.477945619335347
# RMSE: 2.1161156913872516

# %% [markdown]
# ###### Calculate the R2

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predictions)
# Out:
# 0.8978389105220416
